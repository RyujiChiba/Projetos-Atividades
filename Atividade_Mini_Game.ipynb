# %% [markdown]
# <a href="https://colab.research.google.com/github/RyujiChiba/Projetos/blob/main/Atividade_Mini_Game.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Forca

# %%
words = ["abacaxi", "abajur", "abelha", "abóbora", "abraço", "academia", "açaí", "açúcar",
 "adeus", "adubo", "aeródromo", "afeto", "agenda", "agente", "agricultura", "água",
 "águia", "ajuda", "alameda", "alface", "algodão", "alho", "aliança", "alimento",
 "almofada", "aluguel", "amanhecer", "amarelo", "ambiente", "ameixa", "amendoim",
 "amor", "ampulheta", "ananás", "anel", "aniversário", "anjo", "antena", "anzol",
 "aparelho", "apartamento", "apito", "aprendiz", "aquário", "aranha", "arco", "areia",
 "armadilha", "armário", "arquitetura", "arroz", "arte", "artista", "asa", "asfalto",
 "asilo", "aspirador", "assado", "assobio", "astro", "atleta", "atlas", "atmosfera",
 "atum", "aula", "aurora", "avestruz", "avião", "avó", "azul", "babosa", "bacalhau",
 "bacia", "balança", "balão", "balcão", "balde", "baleia", "banana", "bandeira", "banheiro",
 "banho", "banqueta", "baralho", "barata", "barba", "barco", "barulho", "basquete", "bateria",
 "batida", "batom", "bazar", "bebê", "beijo", "beleza", "bengala", "berço", "bermuda", "bicicleta",
 "bigode", "bilhete", "biologia", "bisavó", "biscoito", "bisnaga", "bisturi", "blusa", "boi", "bola",
 "bolacha", "bolha", "bolinho", "bolso", "bomba", "boneca", "boné", "bônus", "borda", "borboleta", "bordado",
 "botão", "branco", "brasa", "brasil", "bravo", "brecha", "brilho", "brinde", "brinquedo", "broa", "broca", "bruxa",
 "bule", "bumerangue", "buraco", "busca", "cabeça", "cabelo", "cabide", "cabo", "cacau", "cachorro", "cadeado", "cadeira",
 "caderno", "café", "caixa", "cajado", "caju", "calça", "calendário", "calma", "camarão", "cambalhota", "camelo", "câmera",
 "caminhão", "caminho", "camisa", "camiseta", "campeonato", "campo", "canário", "caneca", "caneta", "canhão", "canoa", "canto",
 "capa", "capacete", "capim", "capítulo", "carambola", "caranguejo", "carinho", "carnaval", "carro", "carta", "casa", "cascata",
 "casco", "castelo", "castanha", "catarata", "catavento", "cebola", "cédula", "cela", "celular", "cemitério", "centauro", "centro",
 "cerâmica", "cereja", "cerrado", "certeza", "cesta", "chá", "chave", "chefe", "cheiro", "chifre", "chimarrão", "chocolate",
 "choque", "chorão", "chuva", "ciência", "cílios", "cinema", "cinza", "cinto", "circo", "cisne", "citação", "cidade", "cigarra",
 "cilindro", "cimento", "cinzeiro", "cirurgia", "clareira", "clima", "clube", "coala", "cobertor", "cobra", "coco", "código",
 "coelho", "cogumelo", "cola", "colar", "colchão", "colher", "colina", "colisão", "colmeia", "colônia", "colorido", "comédia",
 "comida", "companhia", "comparação", "competição", "composto", "computador", "comum", "concha", "condor", "confete", "confiança",
 "confronto", "congelado", "conjunto", "conquista", "conselho", "constelação", "construção", "contato", "conto", "contraste",
 "controle", "conversa", "convite", "copa", "cópia", "coral", "corda", "coroa", "corredor", "corrente", "cortina", "coruja",
 "cosméticos", "costela", "costume", "cotovelo", "couro", "cozinheiro", "crachá", "cravo", "credencial", "crepúsculo", "crescente",
 "criado", "crime", "crise", "cristal", "crocodilo", "cronômetro", "cruz", "cubo", "cueca", "cultura", "curativo", "curioso",
 "curva", "custo", "dália", "dado", "dança", "dardo", "data", "debate", "debaixo", "década", "decoração", "dedal", "dedo", "defesa",
 "deficiente", "degrau", "delícia", "demora", "denso", "dentista", "depósito", "derrota", "desafio", "desenho", "deserto",
 "desfile", "desgaste", "desistência", "deslize", "desodorante", "despedida", "despesa", "destino", "detalhe", "detetive",
 "deusa", "diadema", "diamante", "diário", "dicionário", "dieta", "diferença", "dificuldade", "digital", "dignidade", "dilúvio",
 "dimensão", "dinâmica", "dinossauro", "diploma", "direção", "direito", "disco", "disfarce", "disquete", "distância",
 "distribuição", "diversão", "divisão", "doce", "documento", "doente", "dominó", "dono", "dor", "dormitório", "dragão",
 "drama", "droga", "ducha", "duelo", "duna", "dupla", "dúvida", "ebulição", "ecologia", "economia", "edifício", "edição",
 "educado", "efeito", "eficiente", "egoísta", "elástico", "elétrico", "elefante", "elevador", "elipse", "embalagem", "embaixador",
 "emenda", "emergência", "emoção", "empada", "empate", "emprego", "empresa", "encontro", "endereço", "energia", "enfeite", "engano",
 "engenheiro", "enigma", "ensaio", "ensino", "entalhe", "enteado", "entidade", "entorno", "entrada", "envelope", "enxame",
 "enxoval", "epopeia", "equação", "equilíbrio", "equipamento", "era", "erro", "escada", "escala", "escama", "escândalo", "escaravelho",
 "escavação", "esconderijo", "escopo", "escorpião", "escova", "escravo", "escudo", "escultura", "esfera", "esgoto", "esmalte",
 "esmeralda", "espetáculo", "espinha", "espiral", "esponja", "esporte", "espremedor", "esquadrão", "esquema", "esquilo", "esquina",
 "estádio", "estágio", "estampa", "estante", "estatística"]

lives_visual_dict = {
 0: """
 ___________
 | / |
 |/ ( )
 | |
 | / \\
 |
 """,
 1: """
 ___________
 | / |
 |/ ( )
 | |
 | /
 |
 """,
 2: """
 ___________
 | / |
 |/ ( )
 | |
 |
 |
 """,
 3: """
 ___________
 | / |
 |/ ( )
 |
 |
 |
 """,
 4: """
 ___________
 | / |
 |/
 |
 |
 |
 """,
 5: """
 ___________
 | /
 |/
 |
 |
 |
 """,
 6: """
 |
 |
 |
 |
 |
 """,
 7: "",
 }
import random
import string

def get_valid_word(words):
    word = random.choice(words)
    while '-' in word or ' ' in word:
        word = random.choice(words)
    return word.upper()

def hangman():
    words = ["ELEFANTE", "GIRASSOL", "BICICLETA"] # Palavras para o jogo
    word = get_valid_word(words)
    word_letters = set(word)
    alphabet = set(string.ascii_uppercase)
    used_letters = set()
    lives = 9

    while len(word_letters) > 0 and lives > 0:
        print('You have', lives, 'lives left and you have used these letters: ', ' '.join(used_letters))

        word_list = [letter if letter in used_letters else '-' for letter in word]
        print(' '.join(word_list))

        user_letter = input('Escolha uma letra: ').upper()

        if user_letter in alphabet - used_letters:
            used_letters.add(user_letter)
            if user_letter in word_letters:
                word_letters.remove(user_letter)
        else:
            lives = lives - 1
            print('\nSua letra,', user_letter, 'não está na palavra.')

        if user_letter in used_letters:
            print('\nVocê já escolheu essa letra, tente outra.')
        else:
            print('\nIsso não é uma letra válida.')

    if lives == 0:
        print('You are dead. A palavra era', word)
    else:
        print('YAY! Você acertou a palavra', word, '!!')

if __name__ == '__main__':
    hangman()

# %% [markdown]
# # Jan Ken po

# %%
import random

def is_win(player, opponent):

    if (player == 'r' and opponent == 's') or (player == 's' and opponent == 'p') \
    or (player == 'p' and opponent == 'r'):
        return True
    else:
        return False

def play():
    user = input("Qual sua escolha? 'r' para pedra, 'p' para papel, 's' para tesoura\n")
    if user not in ['r', 'p', 's']:
        return "Escolha inválida"
    computer = random.choice(['r', 'p', 's'])
    if user == computer:
        resultado = 'Empate'

    elif is_win(user, computer):
        resultado = 'Você ganhou!'
    else:
        resultado = "Você perdeu!"
    return resultado

print(play())
